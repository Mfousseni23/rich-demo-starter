# %% [markdown]
# <a href="https://colab.research.google.com/github/Mfousseni23/rich-demo-starter/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Provided data
data = {
    'Year': [1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010],
    'Unemployment_Rate': [9.8, 12, 8, 7.2, 6.9, 7, 6.5, 6.2, 5.5, 6.3]
}

# Create DataFrame
df = pd.DataFrame(data, columns=['Year', 'Unemployment_Rate'])
df
# Out:
#    Year  Unemployment_Rate
# 0  1920                9.8
# 1  1930               12.0
# 2  1940                8.0
# 3  1950                7.2
# 4  1960                6.9
# 5  1970                7.0
# 6  1980                6.5
# 7  1990                6.2
# 8  2000                5.5
# 9  2010                6.3

# %%
plt.figure(figsize=(10,6))

plt.bar(df['Year'], df['Unemployment_Rate'])

plt.title("Unemployment Rate by Year")
plt.xlabel("Year")
plt.ylabel("Unemployment Rate (%)")

plt.xticks(df['Year'], rotation=45)

plt.show()
